# %%
#importing libraries

import pandas as pd

# %%
#importing dataset

dataset = pd.read_csv(r'C:\Users\Kulde\OneDrive\Desktop\OFFICE\DATASET1\vehicles.csv')

# %%
dataset
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
dataset1 = dataset.copy()

# %%
dataset1.isna().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1205
# manufacturer     17646
# model             5277
# condition       174104
# cylinders       177678
# fuel              3013
# odometer          4400
# title_status      8242
# transmission      2556
# VIN             161042
# drive           130567
# size            306361
# type             92858
# paint_color     130203
# image_url           68
# description         70
# county          426880
# state                0
# lat               6549
# long              6549
# posting_date        68
# dtype: int64

# %%
#Target variable null value check

dataset1['price'].isnull().sum()
# Out:
# 0

# %%
#get the list of coloums which have more than 60 percent null values

removed_columns = []
datasetrows = len(dataset1)

for i in dataset1.columns:                       
    if dataset1[i].isnull().sum() > datasetrows*0.4:
        removed_columns.append(i)
removed_columns
# Out:
# ['condition', 'cylinders', 'size', 'county']

# %%
#Drop the coloums which have more than 60 percent null values

dataset1.drop(columns=removed_columns,inplace=True)
print(len(dataset1.columns))
dataset1.columns
# Out:
# 22
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'fuel', 'odometer', 'title_status', 'transmission', 'VIN',
#        'drive', 'type', 'paint_color', 'image_url', 'description', 'state',
#        'lat', 'long', 'posting_date'],
#       dtype='object')

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   fuel          423867 non-null  object
#  9   odometer      422480 non-null  float64
#  10  title_status  418638 non-null  object
#  11  transmission  424324 non-null  object
#  12  VIN           265838 non-null  object
#  13  drive         296313 non-null  object
#  14  type          334022 non-null  object
#  15  paint_color   296677 non-null  object
#  16  image_url     426812 non-null  object
# ...

# %%
dataset1['price'].value_counts().head()
# Out:
# price
# 0       32895
# 6995     3169
# 7995     3129
# 9995     2867
# 8995     2837
# Name: count, dtype: int64

# %%
for i in dataset1.columns:
    print(dataset1[i].value_counts().head())
# Out:
# id
# 7222695916    1
# 7313139418    1
# 7313423023    1
# 7313423324    1
# 7313424533    1
# Name: count, dtype: int64
# url
# https://prescott.craigslist.org/cto/d/prescott-2010-ford-ranger/7222695916.html            1
# https://nh.craigslist.org/cto/d/troy-1998-dodge-ram-59-cummins/7313139418.html             1
# https://nh.craigslist.org/ctd/d/north-hampton-2012-hyundai-sante-fe-se/7313423023.html     1
# https://nh.craigslist.org/ctd/d/derry-2008-chrysler-sebring-limited-all/7313423324.html    1
# https://nh.craigslist.org/ctd/d/derry-2002-toyota-camry-low-miles/7313424533.html          1
# Name: count, dtype: int64
# region
# columbus                   3608
# jacksonville               3562
# spokane / coeur d'alene    2988
# eugene                     2985
# fresno / madera            2983
# Name: count, dtype: int64
# region_url
# https://spokane.craigslist.org    2988
# https://eugene.craigslist.org     2985
# https://fresno.craigslist.org     2983
# ...

# %%
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 200)

# %%
dataset1
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
import pandas as pd

# Set pandas to display only 20 rows
pd.set_option('display.max_rows', 200)

# %%
dataset1[dataset1['price']==0].head(100)
# Out:
#               id                                                url  \
# 10    7218893038  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 11    7218325704  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 12    7217788283  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 13    7217147606  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 14    7209027818  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 46    7315039307  https://auburn.craigslist.org/ctd/d/auburn-999...
# 126   7305672709  https://auburn.craigslist.org/ctd/d/ozark-2018...
# 127   7305672266  https://auburn.craigslist.org/ctd/d/ozark-2019...
# 128   7305672252  https://auburn.craigslist.org/ctd/d/ozark-2018...
# 191   7316755272  https://bham.craigslist.org/ctd/d/de-armanvill...
# 239   7316237340  https://bham.craigslist.org/ctd/d/de-armanvill...
# 242   7316211151  https://bham.craigslist.org/ctd/d/la-vergne-fr...
# 244   7316198338  https://bham.craigslist.org/ctd/d/cullman-2017...
# ...

# %%
dataset1
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
dataset1.nunique()
# Out:
# id              426880
# url             426880
# region             404
# region_url         413
# price            15655
# year               114
# manufacturer        42
# model            29667
# fuel                 5
# odometer        104870
# title_status         6
# transmission         3
# VIN             118264
# drive                3
# type                13
# paint_color         12
# image_url       241899
# description     360911
# state               51
# lat              53181
# long             53772
# posting_date    381536
# dtype: int64

# %%
dataset1.duplicated().sum()
# Out:
# 0

# %%
columns_to_drop  = ['id','region','posting_date' ,'url', 'region_url', 'VIN', 'image_url', 'description','lat','long']
dataset1.drop(columns=columns_to_drop,inplace=True)
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         426880 non-null  int64
#  1   year          425675 non-null  float64
#  2   manufacturer  409234 non-null  object
#  3   model         421603 non-null  object
#  4   fuel          423867 non-null  object
#  5   odometer      422480 non-null  float64
#  6   title_status  418638 non-null  object
#  7   transmission  424324 non-null  object
#  8   drive         296313 non-null  object
#  9   type          334022 non-null  object
#  10  paint_color   296677 non-null  object
#  11  state         426880 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 39.1+ MB

# %%
dataset1.nunique()
# Out:
# price            15655
# year               114
# manufacturer        42
# model            29667
# fuel                 5
# odometer        104870
# title_status         6
# transmission         3
# drive                3
# type                13
# paint_color         12
# state               51
# dtype: int64

# %%
dataset1[dataset1['price'] == 0].head(100)
# Out:
#       price    year   manufacturer                       model    fuel  \
# 10        0     NaN            NaN                         NaN     NaN
# 11        0     NaN            NaN                         NaN     NaN
# 12        0     NaN            NaN                         NaN     NaN
# 13        0     NaN            NaN                         NaN     NaN
# 14        0     NaN            NaN                         NaN     NaN
# 46        0  2011.0           jeep                     compass     gas
# 126       0  2018.0      chevrolet           express cargo van     gas
# 127       0  2019.0      chevrolet           express cargo van     gas
# 128       0  2018.0      chevrolet           express cargo van     gas
# 191       0  2015.0         nissan                      sentra     gas
# 239       0  2019.0      chevrolet              silverado 1500     gas
# 242       0  2014.0            NaN       Freightliner Cascadia  diesel
# ...

# %%
dataset1.duplicated().sum()
# Out:
# 128437

# %%
dataset1 = dataset1.drop_duplicates()

# %%
dataset1 = dataset1.reset_index(drop=True)

# %%
dataset1
# Out:
#         price    year manufacturer                     model    fuel  \
# 0        6000     NaN          NaN                       NaN     NaN
# 1       11900     NaN          NaN                       NaN     NaN
# 2       21000     NaN          NaN                       NaN     NaN
# 3        1500     NaN          NaN                       NaN     NaN
# 4        4900     NaN          NaN                       NaN     NaN
# ...       ...     ...          ...                       ...     ...
# 298438  23590  2019.0       nissan         maxima s sedan 4d     gas
# 298439  30590  2020.0        volvo  s60 t5 momentum sedan 4d     gas
# 298440  34990  2020.0     cadillac          xt4 sport suv 4d  diesel
# 298441  28990  2018.0        lexus           es 350 sedan 4d     gas
# 298442  30590  2019.0          bmw  4 series 430i gran coupe     gas
#
#         odometer title_status transmission drive       type paint_color state
# ...

# %%
dataset1.isna().sum()
# Out:
# price               0
# year              869
# manufacturer    13024
# model            4240
# fuel             1881
# odometer         2692
# title_status     4703
# transmission     1603
# drive           88020
# type            68633
# paint_color     87341
# state               0
# dtype: int64

# %%
dataset1.duplicated().sum()
# Out:
# 0

# %%
dataset1.head(20)
# Out:
#     price    year manufacturer                     model fuel  odometer  \
# 0    6000     NaN          NaN                       NaN  NaN       NaN
# 1   11900     NaN          NaN                       NaN  NaN       NaN
# 2   21000     NaN          NaN                       NaN  NaN       NaN
# 3    1500     NaN          NaN                       NaN  NaN       NaN
# 4    4900     NaN          NaN                       NaN  NaN       NaN
# 5    1600     NaN          NaN                       NaN  NaN       NaN
# 6    1000     NaN          NaN                       NaN  NaN       NaN
# 7   15995     NaN          NaN                       NaN  NaN       NaN
# 8    5000     NaN          NaN                       NaN  NaN       NaN
# 9    3000     NaN          NaN                       NaN  NaN       NaN
# 10      0     NaN          NaN                       NaN  NaN       NaN
# 11  13995     NaN          NaN                       NaN  NaN       NaN
# ...

# %%
dataset1.isna().sum()
# Out:
# price               0
# year              869
# manufacturer    13024
# model            4240
# fuel             1881
# odometer         2692
# title_status     4703
# transmission     1603
# drive           88020
# type            68633
# paint_color     87341
# state               0
# dtype: int64

# %%
dataset1[dataset1.drop(['price','state'],axis=1).isnull().all(axis=1)]
# Out:
#         price  year manufacturer model fuel  odometer title_status  \
# 0        6000   NaN          NaN   NaN  NaN       NaN          NaN
# 1       11900   NaN          NaN   NaN  NaN       NaN          NaN
# 2       21000   NaN          NaN   NaN  NaN       NaN          NaN
# 3        1500   NaN          NaN   NaN  NaN       NaN          NaN
# 4        4900   NaN          NaN   NaN  NaN       NaN          NaN
# 5        1600   NaN          NaN   NaN  NaN       NaN          NaN
# 6        1000   NaN          NaN   NaN  NaN       NaN          NaN
# 7       15995   NaN          NaN   NaN  NaN       NaN          NaN
# 8        5000   NaN          NaN   NaN  NaN       NaN          NaN
# 9        3000   NaN          NaN   NaN  NaN       NaN          NaN
# 10          0   NaN          NaN   NaN  NaN       NaN          NaN
# 11      13995   NaN          NaN   NaN  NaN       NaN          NaN
# 12      24999   NaN          NaN   NaN  NaN       NaN          NaN
# ...

# %%
#remove rows which have nan values except price and state

dataset1 = dataset1[~dataset1.drop(['price','state'],axis=1).isnull().all(axis=1)]
dataset1.reset_index(drop=True)
# Out:
#         price    year manufacturer                     model    fuel  \
# 0       33590  2014.0          gmc  sierra 1500 crew cab slt     gas
# 1       22590  2010.0    chevrolet            silverado 1500     gas
# 2       39590  2020.0    chevrolet       silverado 1500 crew     gas
# 3       30990  2017.0       toyota      tundra double cab sr     gas
# 4       15000  2013.0         ford                 f-150 xlt     gas
# ...       ...     ...          ...                       ...     ...
# 298383  23590  2019.0       nissan         maxima s sedan 4d     gas
# 298384  30590  2020.0        volvo  s60 t5 momentum sedan 4d     gas
# 298385  34990  2020.0     cadillac          xt4 sport suv 4d  diesel
# 298386  28990  2018.0        lexus           es 350 sedan 4d     gas
# 298387  30590  2019.0          bmw  4 series 430i gran coupe     gas
#
#         odometer title_status transmission drive       type paint_color state
# ...

# %%
#rows whihc have duplicates except column price is removed

dataset1 = dataset1[~dataset1.drop('price',axis=1).duplicated()]
dataset1
# Out:
#         price    year manufacturer                     model    fuel  \
# 17      33590  2014.0          gmc  sierra 1500 crew cab slt     gas
# 18      22590  2010.0    chevrolet            silverado 1500     gas
# 19      39590  2020.0    chevrolet       silverado 1500 crew     gas
# 20      30990  2017.0       toyota      tundra double cab sr     gas
# 21      15000  2013.0         ford                 f-150 xlt     gas
# ...       ...     ...          ...                       ...     ...
# 298438  23590  2019.0       nissan         maxima s sedan 4d     gas
# 298439  30590  2020.0        volvo  s60 t5 momentum sedan 4d     gas
# 298440  34990  2020.0     cadillac          xt4 sport suv 4d  diesel
# 298441  28990  2018.0        lexus           es 350 sedan 4d     gas
# 298442  30590  2019.0          bmw  4 series 430i gran coupe     gas
#
#         odometer title_status transmission drive       type paint_color state
# ...

# %%
dataset1
# Out:
#         price    year manufacturer                     model    fuel  \
# 17      33590  2014.0          gmc  sierra 1500 crew cab slt     gas
# 18      22590  2010.0    chevrolet            silverado 1500     gas
# 19      39590  2020.0    chevrolet       silverado 1500 crew     gas
# 20      30990  2017.0       toyota      tundra double cab sr     gas
# 21      15000  2013.0         ford                 f-150 xlt     gas
# ...       ...     ...          ...                       ...     ...
# 298438  23590  2019.0       nissan         maxima s sedan 4d     gas
# 298439  30590  2020.0        volvo  s60 t5 momentum sedan 4d     gas
# 298440  34990  2020.0     cadillac          xt4 sport suv 4d  diesel
# 298441  28990  2018.0        lexus           es 350 sedan 4d     gas
# 298442  30590  2019.0          bmw  4 series 430i gran coupe     gas
#
#         odometer title_status transmission drive       type paint_color state
# ...

# %%
dataset1['price'].value_counts().head()
# Out:
# price
# 0       19474
# 4500     2459
# 3500     2404
# 5500     2284
# 6500     2269
# Name: count, dtype: int64

# %%
dataset1 = dataset1[(dataset1['price'] > 100) & (dataset1['price'] < 60000)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Boxplot for the price column
plt.figure(figsize=(15, 5))
ax = sns.boxplot(dataset1, x='price')
plt.title('Boxplot of Price with Outliers')
plt.xlabel('Price')
plt.xticks(rotation=90)
ax.set_xlim(-10000, 60000)

# Set x-axis formatter to avoid scientific notation
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.show()

# %%
# Boxplot for the price column
plt.figure(figsize=(15, 5))
ax = sns.boxplot(dataset1, x='price')
plt.title('Boxplot of Price with Outliers')
plt.xlabel('Price')
plt.xticks(rotation=90)
# ax.set_xlim(-10000, 70000)

# Set x-axis formatter to avoid scientific notation
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.show()

# %%
plt.figure(figsize=(15, 5))
ax = sns.boxplot(dataset1, x='odometer')
plt.title('Boxplot of Price with Outliers')
plt.xlabel('Price')
plt.xticks(rotation=90)
ax.set_xlim(-10000, 400000)

# Set x-axis formatter to avoid scientific notation
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.show()

# %%
dataset1 = dataset1[dataset1['odometer'] < 300000]

# %%
dataset1
# Out:
#         price    year manufacturer                     model    fuel  \
# 17      33590  2014.0          gmc  sierra 1500 crew cab slt     gas
# 18      22590  2010.0    chevrolet            silverado 1500     gas
# 19      39590  2020.0    chevrolet       silverado 1500 crew     gas
# 20      30990  2017.0       toyota      tundra double cab sr     gas
# 21      15000  2013.0         ford                 f-150 xlt     gas
# ...       ...     ...          ...                       ...     ...
# 298438  23590  2019.0       nissan         maxima s sedan 4d     gas
# 298439  30590  2020.0        volvo  s60 t5 momentum sedan 4d     gas
# 298440  34990  2020.0     cadillac          xt4 sport suv 4d  diesel
# 298441  28990  2018.0        lexus           es 350 sedan 4d     gas
# 298442  30590  2019.0          bmw  4 series 430i gran coupe     gas
#
#         odometer title_status transmission drive       type paint_color state
# ...

# %%
dataset1.reset_index(drop=True)
# Out:
#         price    year manufacturer                     model    fuel  \
# 0       33590  2014.0          gmc  sierra 1500 crew cab slt     gas
# 1       22590  2010.0    chevrolet            silverado 1500     gas
# 2       39590  2020.0    chevrolet       silverado 1500 crew     gas
# 3       30990  2017.0       toyota      tundra double cab sr     gas
# 4       15000  2013.0         ford                 f-150 xlt     gas
# ...       ...     ...          ...                       ...     ...
# 263714  23590  2019.0       nissan         maxima s sedan 4d     gas
# 263715  30590  2020.0        volvo  s60 t5 momentum sedan 4d     gas
# 263716  34990  2020.0     cadillac          xt4 sport suv 4d  diesel
# 263717  28990  2018.0        lexus           es 350 sedan 4d     gas
# 263718  30590  2019.0          bmw  4 series 430i gran coupe     gas
#
#         odometer title_status transmission drive       type paint_color state
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263719 entries, 17 to 298442
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         263719 non-null  int64
#  1   year          263079 non-null  float64
#  2   manufacturer  253056 non-null  object
#  3   model         260418 non-null  object
#  4   fuel          262312 non-null  object
#  5   odometer      263719 non-null  float64
#  6   title_status  259967 non-null  object
#  7   transmission  262729 non-null  object
#  8   drive         187092 non-null  object
#  9   type          203940 non-null  object
#  10  paint_color   190074 non-null  object
#  11  state         263719 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 26.2+ MB

# %%
dataset1['paint_color'].value_counts()
# Out:
# paint_color
# white     48201
# black     39210
# silver    27985
# blue      20477
# red       19448
# grey      16910
# green      5292
# custom     4789
# brown      4476
# yellow     1521
# orange     1251
# purple      514
# Name: count, dtype: int64

# %%
dataset1['paint_color'].isnull().sum()
# Out:
# 73645

# %%
dataset1 = dataset1.drop(columns=['drive']).dropna(subset=['type','year','paint_color'])

# %%
dataset1
# Out:
#         price    year   manufacturer                     model    fuel  \
# 17      33590  2014.0            gmc  sierra 1500 crew cab slt     gas
# 18      22590  2010.0      chevrolet            silverado 1500     gas
# 19      39590  2020.0      chevrolet       silverado 1500 crew     gas
# 20      30990  2017.0         toyota      tundra double cab sr     gas
# 21      15000  2013.0           ford                 f-150 xlt     gas
# ...       ...     ...            ...                       ...     ...
# 298436  30990  2018.0  mercedes-benz             glc 300 sport     gas
# 298437  33590  2018.0          lexus           gs 350 sedan 4d     gas
# 298439  30590  2020.0          volvo  s60 t5 momentum sedan 4d     gas
# 298440  34990  2020.0       cadillac          xt4 sport suv 4d  diesel
# 298441  28990  2018.0          lexus           es 350 sedan 4d     gas
#
#         odometer title_status transmission       type paint_color state
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170578 entries, 17 to 298441
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         170578 non-null  int64
#  1   year          170578 non-null  float64
#  2   manufacturer  164840 non-null  object
#  3   model         169165 non-null  object
#  4   fuel          169770 non-null  object
#  5   odometer      170578 non-null  float64
#  6   title_status  170126 non-null  object
#  7   transmission  169916 non-null  object
#  8   type          170578 non-null  object
#  9   paint_color   170578 non-null  object
#  10  state         170578 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 15.6+ MB

# %%
dataset1
# Out:
#         price    year   manufacturer                     model    fuel  \
# 17      33590  2014.0            gmc  sierra 1500 crew cab slt     gas
# 18      22590  2010.0      chevrolet            silverado 1500     gas
# 19      39590  2020.0      chevrolet       silverado 1500 crew     gas
# 20      30990  2017.0         toyota      tundra double cab sr     gas
# 21      15000  2013.0           ford                 f-150 xlt     gas
# ...       ...     ...            ...                       ...     ...
# 298436  30990  2018.0  mercedes-benz             glc 300 sport     gas
# 298437  33590  2018.0          lexus           gs 350 sedan 4d     gas
# 298439  30590  2020.0          volvo  s60 t5 momentum sedan 4d     gas
# 298440  34990  2020.0       cadillac          xt4 sport suv 4d  diesel
# 298441  28990  2018.0          lexus           es 350 sedan 4d     gas
#
#         odometer title_status transmission       type paint_color state
# ...

# %%
dataset1['year'] = dataset1['year'].astype(int)
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170578 entries, 17 to 298441
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         170578 non-null  int64
#  1   year          170578 non-null  int32
#  2   manufacturer  164840 non-null  object
#  3   model         169165 non-null  object
#  4   fuel          169770 non-null  object
#  5   odometer      170578 non-null  float64
#  6   title_status  170126 non-null  object
#  7   transmission  169916 non-null  object
#  8   type          170578 non-null  object
#  9   paint_color   170578 non-null  object
#  10  state         170578 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 15.0+ MB

# %%
dataset1['price'].value_counts()
# Out:
# price
# 4500     1417
# 3500     1405
# 6500     1367
# 7995     1366
# 6995     1362
#          ...
# 391         1
# 694         1
# 593         1
# 983         1
# 17873       1
# Name: count, Length: 10639, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Boxplot for the price column
plt.figure(figsize=(15, 5))
ax = sns.boxplot(dataset1, x='manufacturer')
plt.title('Boxplot of Price with Outliers')
plt.xlabel('Price')
plt.xticks(rotation=90)
# ax.set_xlim(-10000, 60000)

# Set x-axis formatter to avoid scientific notation
# plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.show()

# %%
dataset1['transmission'].value_counts()
# Out:
# transmission
# automatic    131692
# other         27151
# manual        11073
# Name: count, dtype: int64

# %%
dataset1['type'].value_counts()
# Out:
# type
# sedan          46487
# SUV            40114
# pickup         19440
# truck          17027
# coupe          10485
# other           9365
# hatchback       9131
# wagon           5574
# convertible     4663
# van             4454
# mini-van        3016
# offroad          483
# bus              339
# Name: count, dtype: int64

# %%
dataset1['paint_color'].value_counts()
# Out:
# paint_color
# white     42308
# black     35597
# silver    25284
# blue      18468
# red       17400
# grey      15360
# green      4652
# custom     4604
# brown      4129
# yellow     1245
# orange     1079
# purple      452
# Name: count, dtype: int64

# %%
dataset1['state'].value_counts()
# Out:
# state
# ca    17057
# fl    11136
# tx     9846
# ny     8180
# oh     6558
# pa     5972
# co     5452
# mi     5226
# or     5051
# nc     4916
# il     4652
# tn     4549
# wa     4492
# nj     4492
# wi     4477
# az     4295
# ma     4172
# id     3872
# va     3821
# mn     3563
# ia     3344
# ga     3106
# ks     2712
# in     2616
# sc     2577
# ct     2494
# ok     2440
# md     2301
# al     2025
# nm     2017
# ky     1999
# nv     1855
# dc     1811
# mt     1806
# mo     1667
# nh     1439
# ak     1420
# vt     1308
# ri     1243
# ar     1223
# me     1203
# hi     1162
# la     1100
# ut      675
# sd      572
# ne      539
# de      514
# wv      510
# ms      487
# wy      378
# nd      256
# Name: count, dtype: int64

# %%
dataset1['manufacturer'].isnull().sum()
# Out:
# 5738

# %%
dataset1['manufacturer'].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Kulde\AppData\Local\Temp\ipykernel_3800\891868512.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset1['manufacturer'].fillna("Unknown",inplace=True)

# %%
dataset1['manufacturer'].isnull().sum()
# Out:
# 0

# %%
dataset1[dataset1['manufacturer'] == 'Unknown']
# Out:
#         price  year manufacturer                           model    fuel  \
# 87      15990  2016      Unknown           Scion iM Hatchback 4D     gas
# 112      6800  2005      Unknown                   blue bird bus  diesel
# 125     14990  2016      Unknown           Scion iM Hatchback 4D     gas
# 127      2500  1966      Unknown                 1966 C-30 1 ton     gas
# 145      8990  2013      Unknown  smart fortwo Passion Hatchback     gas
# ...       ...   ...          ...                             ...     ...
# 298394  12590  2012      Unknown           Scion xD Hatchback 4D     gas
# 298407  21900  1920      Unknown         Paige Glenbrook Touring     gas
# 298426  27590  2018      Unknown        Genesis G80 3.8 Sedan 4D     gas
# 298427  25590  2017      Unknown        Genesis G80 3.8 Sedan 4D     gas
# 298432  13990  2016      Unknown           Scion iM Hatchback 4D   other
#
#         odometer title_status transmission       type paint_color state
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Boxplot for the price column
plt.figure(figsize=(15, 5))
ax = sns.boxplot(dataset1, x='manufacturer')
plt.title('Boxplot of Price with Outliers')
plt.xlabel('Price')
plt.xticks(rotation=90)
# ax.set_xlim(-10000, 60000)

# Set x-axis formatter to avoid scientific notation
# plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.show()

# %%
dataset1['manufacturer'].value_counts()
# Out:
# manufacturer
# ford               26731
# chevrolet          20884
# toyota             14284
# honda               9495
# nissan              8119
# jeep                7313
# bmw                 6430
# ram                 6113
# gmc                 5997
# Unknown             5738
# dodge               5152
# mercedes-benz       4898
# hyundai             4357
# volkswagen          4344
# subaru              4331
# lexus               3464
# kia                 3427
# audi                3427
# cadillac            2946
# acura               2605
# chrysler            2490
# mazda               2318
# buick               2230
# infiniti            2133
# lincoln             1722
# volvo               1490
# mitsubishi          1460
# mini                1123
# pontiac             1003
# jaguar               975
# rover                904
# porsche              538
# mercury              533
# saturn               468
# alfa-romeo           408
# fiat                 340
# ...

# %%
#dataset1['manufacturer'] = dataset1['manufacturer'].where(dataset1['manufacturer'].map(dataset1['manufacturer'].value_counts()) >= 5000, 'Other')

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170578 entries, 17 to 298441
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         170578 non-null  int64
#  1   year          170578 non-null  int32
#  2   manufacturer  170578 non-null  object
#  3   model         169165 non-null  object
#  4   fuel          169770 non-null  object
#  5   odometer      170578 non-null  float64
#  6   title_status  170126 non-null  object
#  7   transmission  169916 non-null  object
#  8   type          170578 non-null  object
#  9   paint_color   170578 non-null  object
#  10  state         170578 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 15.0+ MB

# %%
dataset1['model'].isnull().sum()
# Out:
# 1413

# %%
dataset1.dropna(subset=['model'],inplace=True)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169165 entries, 17 to 298441
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         169165 non-null  int64
#  1   year          169165 non-null  int32
#  2   manufacturer  169165 non-null  object
#  3   model         169165 non-null  object
#  4   fuel          168357 non-null  object
#  5   odometer      169165 non-null  float64
#  6   title_status  168713 non-null  object
#  7   transmission  168513 non-null  object
#  8   type          169165 non-null  object
#  9   paint_color   169165 non-null  object
#  10  state         169165 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 14.8+ MB

# %%
dataset1['model'] = dataset1['model'].str.split().str.slice(0,3).str.join(' ')

# %%
dataset1['model'].nunique()
# Out:
# 16459

# %%
#dataset1['model'].where(dataset1['model'].map(dataset1['model'].value_counts()) >= 1000, 'Other').value_counts()

# %%
dataset1['model'].value_counts()
# Out:
# model
# f-150                          2874
# silverado 1500                 1912
# 1500                           1455
# accord                         1321
# camry                          1284
#                                ...
# f-550 xl super                    1
# c-max sel                         1
# express 2500 9                    1
# Keystone Springdale 202QBWE       1
# Paige Glenbrook Touring           1
# Name: count, Length: 16459, dtype: int64

# %%
dataset1['model']
# Out:
# 17           sierra 1500 crew
# 18             silverado 1500
# 19        silverado 1500 crew
# 20          tundra double cab
# 21                  f-150 xlt
#                  ...
# 298436          glc 300 sport
# 298437           gs 350 sedan
# 298439        s60 t5 momentum
# 298440          xt4 sport suv
# 298441           es 350 sedan
# Name: model, Length: 169165, dtype: object

# %%
dataset1['fuel'].value_counts()
# Out:
# fuel
# gas         144877
# other        12020
# diesel        8462
# hybrid        2295
# electric       703
# Name: count, dtype: int64

# %%
dataset1['fuel'].isnull().sum()
# Out:
# 808

# %%
dataset1['fuel'].value_counts().idxmax()
# Out:
# 'gas'

# %%
dataset1['fuel'].fillna(dataset1['fuel'].value_counts().idxmax(),inplace=True)
# Out:
# C:\Users\Kulde\AppData\Local\Temp\ipykernel_3800\3245901320.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset1['fuel'].fillna(dataset1['fuel'].value_counts().idxmax(),inplace=True)

# %%
dataset1['fuel'].isnull().sum()
# Out:
# 0

# %%
dataset1['fuel'].value_counts()
# Out:
# fuel
# gas         145685
# other        12020
# diesel        8462
# hybrid        2295
# electric       703
# Name: count, dtype: int64

# %%
dataset1['odometer'].value_counts()
# Out:
# odometer
# 200000.0    719
# 150000.0    638
# 100000.0    604
# 160000.0    510
# 140000.0    505
#            ...
# 113345.0      1
# 92384.0       1
# 160667.0      1
# 72502.0       1
# 11065.0       1
# Name: count, Length: 71344, dtype: int64

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169165 entries, 17 to 298441
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         169165 non-null  int64
#  1   year          169165 non-null  int32
#  2   manufacturer  169165 non-null  object
#  3   model         169165 non-null  object
#  4   fuel          169165 non-null  object
#  5   odometer      169165 non-null  float64
#  6   title_status  168713 non-null  object
#  7   transmission  168513 non-null  object
#  8   type          169165 non-null  object
#  9   paint_color   169165 non-null  object
#  10  state         169165 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 14.8+ MB

# %%
dataset1['odometer'].isnull().sum()
# Out:
# 0

# %%
dataset1['odometer'] = dataset1['odometer'].astype(int)

# %%
dataset1
# Out:
#         price  year   manufacturer                model    fuel  odometer  \
# 17      33590  2014            gmc     sierra 1500 crew     gas     57923
# 18      22590  2010      chevrolet       silverado 1500     gas     71229
# 19      39590  2020      chevrolet  silverado 1500 crew     gas     19160
# 20      30990  2017         toyota    tundra double cab     gas     41124
# 21      15000  2013           ford            f-150 xlt     gas    128000
# ...       ...   ...            ...                  ...     ...       ...
# 298436  30990  2018  mercedes-benz        glc 300 sport     gas     15080
# 298437  33590  2018          lexus         gs 350 sedan     gas     30814
# 298439  30590  2020          volvo      s60 t5 momentum     gas     12029
# 298440  34990  2020       cadillac        xt4 sport suv  diesel      4174
# 298441  28990  2018          lexus         es 350 sedan     gas     30112
#
#        title_status transmission       type paint_color state
# ...

# %%
dataset1['title_status'].value_counts()
# Out:
# title_status
# clean         161823
# rebuilt         3757
# salvage         1839
# lien             957
# missing          273
# parts only        64
# Name: count, dtype: int64

# %%
dataset1['title_status'].isnull().sum()
# Out:
# 452

# %%
dataset1['title_status'].fillna(dataset1['title_status'].value_counts().idxmax(),inplace=True)
# Out:
# C:\Users\Kulde\AppData\Local\Temp\ipykernel_3800\2202078244.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset1['title_status'].fillna(dataset1['title_status'].value_counts().idxmax(),inplace=True)

# %%
dataset1['title_status'].value_counts()
# Out:
# title_status
# clean         162275
# rebuilt         3757
# salvage         1839
# lien             957
# missing          273
# parts only        64
# Name: count, dtype: int64

# %%
dataset1['title_status'].isnull().sum()
# Out:
# 0

# %%
dataset1['transmission'].isnull().sum()
# Out:
# 652

# %%
dataset1['transmission'].value_counts()
# Out:
# transmission
# automatic    130559
# other         27131
# manual        10823
# Name: count, dtype: int64

# %%
dataset1['transmission'].fillna(dataset1['transmission'].value_counts().idxmax(),inplace=True)
# Out:
# C:\Users\Kulde\AppData\Local\Temp\ipykernel_3800\3556970003.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset1['transmission'].fillna(dataset1['transmission'].value_counts().idxmax(),inplace=True)

# %%
dataset1['transmission'].isnull().sum()
# Out:
# 0

# %%
dataset1['transmission'].value_counts()
# Out:
# transmission
# automatic    131211
# other         27131
# manual        10823
# Name: count, dtype: int64

# %%
dataset1['type'].isnull().sum()
# Out:
# 0

# %%
dataset1['type'].value_counts()
# Out:
# type
# sedan          46301
# SUV            39860
# pickup         19058
# truck          16769
# coupe          10373
# other           9335
# hatchback       9109
# wagon           5560
# convertible     4606
# van             4399
# mini-van        3003
# offroad          463
# bus              329
# Name: count, dtype: int64

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169165 entries, 17 to 298441
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         169165 non-null  int64
#  1   year          169165 non-null  int32
#  2   manufacturer  169165 non-null  object
#  3   model         169165 non-null  object
#  4   fuel          169165 non-null  object
#  5   odometer      169165 non-null  int32
#  6   title_status  169165 non-null  object
#  7   transmission  169165 non-null  object
#  8   type          169165 non-null  object
#  9   paint_color   169165 non-null  object
#  10  state         169165 non-null  object
# dtypes: int32(2), int64(1), object(8)
# memory usage: 14.2+ MB

# %%
dataset1.sample(10)
# Out:
#         price  year manufacturer                  model    fuel  odometer  \
# 260411   8990  2008        lexus                rx 400h  hybrid    115782
# 70447   20921  2011          gmc                  yukon   other    146813
# 115547  16900  2013         ford      f250 turbo diesel  diesel    242221
# 56535    5000  2003         ford          f-150 xlt 4x4     gas    130000
# 259064  28800  2004        lexus                 gx 470     gas    147000
# 218594  23995  2014         audi                     q5  diesel    104800
# 295197   2500  2001      Unknown  oldsmobile silhouette     gas    149000
# 267030   5995  2005    chevrolet       suburban z71 4x4     gas    232000
# 75989    8000  2006          bmw                   550i     gas    119000
# 185257  12475  2012        honda                 crv lx     gas     89544
#
#        title_status transmission      type paint_color state
# 260411        clean    automatic       SUV         red    tx
# ...

# %%
dataset1.reset_index(drop=True,inplace=True)

# %%
dataset1
# Out:
#         price  year   manufacturer                model    fuel  odometer  \
# 0       33590  2014            gmc     sierra 1500 crew     gas     57923
# 1       22590  2010      chevrolet       silverado 1500     gas     71229
# 2       39590  2020      chevrolet  silverado 1500 crew     gas     19160
# 3       30990  2017         toyota    tundra double cab     gas     41124
# 4       15000  2013           ford            f-150 xlt     gas    128000
# ...       ...   ...            ...                  ...     ...       ...
# 169160  30990  2018  mercedes-benz        glc 300 sport     gas     15080
# 169161  33590  2018          lexus         gs 350 sedan     gas     30814
# 169162  30590  2020          volvo      s60 t5 momentum     gas     12029
# 169163  34990  2020       cadillac        xt4 sport suv  diesel      4174
# 169164  28990  2018          lexus         es 350 sedan     gas     30112
#
#        title_status transmission       type paint_color state
# ...

# %%
cleaned_car_csv = dataset1

# %%
cleaned_car_csv
# Out:
#         price  year   manufacturer                model    fuel  odometer  \
# 0       33590  2014            gmc     sierra 1500 crew     gas     57923
# 1       22590  2010      chevrolet       silverado 1500     gas     71229
# 2       39590  2020      chevrolet  silverado 1500 crew     gas     19160
# 3       30990  2017         toyota    tundra double cab     gas     41124
# 4       15000  2013           ford            f-150 xlt     gas    128000
# ...       ...   ...            ...                  ...     ...       ...
# 169160  30990  2018  mercedes-benz        glc 300 sport     gas     15080
# 169161  33590  2018          lexus         gs 350 sedan     gas     30814
# 169162  30590  2020          volvo      s60 t5 momentum     gas     12029
# 169163  34990  2020       cadillac        xt4 sport suv  diesel      4174
# 169164  28990  2018          lexus         es 350 sedan     gas     30112
#
#        title_status transmission       type paint_color state
# ...

# %%
cleaned_car_csv.to_csv('cleaned_car_csv.csv')

# %%
cleaned_car_csv
# Out:
#         price  year   manufacturer                model    fuel  odometer  \
# 0       33590  2014            gmc     sierra 1500 crew     gas     57923
# 1       22590  2010      chevrolet       silverado 1500     gas     71229
# 2       39590  2020      chevrolet  silverado 1500 crew     gas     19160
# 3       30990  2017         toyota    tundra double cab     gas     41124
# 4       15000  2013           ford            f-150 xlt     gas    128000
# ...       ...   ...            ...                  ...     ...       ...
# 169160  30990  2018  mercedes-benz        glc 300 sport     gas     15080
# 169161  33590  2018          lexus         gs 350 sedan     gas     30814
# 169162  30590  2020          volvo      s60 t5 momentum     gas     12029
# 169163  34990  2020       cadillac        xt4 sport suv  diesel      4174
# 169164  28990  2018          lexus         es 350 sedan     gas     30112
#
#        title_status transmission       type paint_color state
# ...
